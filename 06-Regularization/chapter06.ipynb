# %% [markdown]
# ## Chapter 6
# Snippets for the chapter 6

# %% [markdown]
# First code snippet

# %%
import numpy as np
from plotnine import *
import pandas as pd
# %matplotlib inline

x = np.arange(-10, 10, 0.01)
y = 1 - x*x + np.random.normal(size = len(x), scale = 5)

fig = (
    ggplot(data =  pd.DataFrame({'X': x, 'Y': y}), mapping=aes(x = 'X',  y = 'Y')) +
    geom_point() +
    geom_smooth(se = False)
)

fig
# Out:
# C:\Users\dazb\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\dazb\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# <ggplot: (-9223371945393430503)>

# %% [markdown]
# Second code snippet

# %%
x_squared = x * x

# %% [markdown]
# Third code snippet

# %%
fig = (
    ggplot(data =  pd.DataFrame({'X': x_squared, 'Y': y}), mapping=aes(x = 'X',  y = 'Y')) +
    geom_point() +
    geom_smooth(method = 'lm', se = False)
)

fig
# Out:
# C:\Users\dazb\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\dazb\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# <ggplot: (-9223371945399105820)>

# %% [markdown]
# Fourth code snippet

# %%
import statsmodels.api as sm
from sklearn.metrics import r2_score

model = sm.OLS(y, x).fit()
predictions = model.predict(x) 

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                   0.06510
# Date:                Wed, 19 Jun 2019   Prob (F-statistic):              0.799
# Time:                        15:48:26   Log-Likelihood:                -10421.
# No. Observations:                2000   AIC:                         2.084e+04
# Df Residuals:                    1999   BIC:                         2.085e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0438      0.172      0.255      0.799      -0.293       0.381
# ==============================================================================
# Omnibus:                      286.886   Durbin-Watson:                   0.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              180.911
# Skew:                          -0.614   Prob(JB):                     5.20e-40
# Kurtosis:                       2.184   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import statsmodels.api as sm
from sklearn.metrics import r2_score

model = sm.OLS(y, x_squared).fit()
predictions = model.predict(x_squared) 

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.988
# Model:                            OLS   Adj. R-squared:                  0.988
# Method:                 Least Squares   F-statistic:                 1.595e+05
# Date:                Wed, 19 Jun 2019   Prob (F-statistic):               0.00
# Time:                        15:48:26   Log-Likelihood:                -6029.6
# No. Observations:                2000   AIC:                         1.206e+04
# Df Residuals:                    1999   BIC:                         1.207e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.9851      0.002   -399.340      0.000      -0.990      -0.980
# ==============================================================================
# Omnibus:                        1.082   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.582   Jarque-Bera (JB):                0.992
# Skew:                           0.037   Prob(JB):                        0.609
# Kurtosis:                       3.081   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Fifth code snippet

# %%
x = np.arange(0, 1, 0.01)
y = np.sin(2 * np.pi * x) + np.random.normal(size = len(x), scale = 0.1)

fig = (
    ggplot(data =  pd.DataFrame({'X': x, 'Y': y}), mapping=aes(x = 'X',  y = 'Y')) +
    geom_point()
)

fig
# Out:
# C:\Users\dazb\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\dazb\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# <ggplot: (91462084623)>

# %% [markdown]
# Sixth code snippet

# %%
import statsmodels.api as sm

model = sm.OLS(y, x).fit()
predictions = model.predict(x_squared) 

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.160
# Model:                            OLS   Adj. R-squared:                  0.151
# Method:                 Least Squares   F-statistic:                     18.83
# Date:                Wed, 19 Jun 2019   Prob (F-statistic):           3.45e-05
# Time:                        15:48:26   Log-Likelihood:                -100.24
# No. Observations:                 100   AIC:                             202.5
# Df Residuals:                      99   BIC:                             205.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.5018      0.116     -4.339      0.000      -0.731      -0.272
# ==============================================================================
# Omnibus:                       45.062   Durbin-Watson:                   0.046
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                6.629
# Skew:                           0.001   Prob(JB):                       0.0364
# Kurtosis:                       1.739   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Seventh code snippet

# %%
fig = (
    ggplot(data =  pd.DataFrame({'X': x, 'Y': y}), mapping=aes(x = 'X',  y = 'Y')) +
    geom_point() +
    geom_smooth(method = 'lm', se = False)
)

fig
# Out:
# C:\Users\dazb\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\dazb\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# <ggplot: (91462200454)>

# %% [markdown]
# Eighth code snippet

# %%
from sklearn.metrics import r2_score

coefficients = np.polyfit(x, y, 3)
p = np.poly1d(coefficients)
predicted_values = p(x)
r2_score(y, predicted_values)
# Out:
# 0.9653888376145365

# %% [markdown]
# Ninth code snippet

# %%
performance = pd.DataFrame()

df = pd.DataFrame({'X': x, 'Y': y})
msk = np.random.rand(len(df)) < 0.8
train = df[msk]
test = df[~msk]

for degree in range(1, 15):
    coefficients = np.polyfit(train.X, train.Y, degree)
    p = np.poly1d(coefficients)
    
    predicted_values_train = p(train.X)
    rmse_train = np.sqrt(np.square(predicted_values_train - train.Y).mean())
    performance = performance.append({'Degree': degree, 'Data': 'Training', 'RMSE': rmse_train}, ignore_index=True)
    
    predicted_values_test = p(test.X)
    rmse_test = np.sqrt(np.square(predicted_values_test - test.Y).mean())
    performance = performance.append({'Degree': degree, 'Data': 'Test', 'RMSE': rmse_test}, ignore_index=True)

# %% [markdown]
# Tenth code snippet

# %%
fig = (
    ggplot(data =  performance, mapping=aes(x = 'Degree',  y = 'RMSE', linetype = 'Data')) +
    geom_point() + 
    geom_line()
)

fig
# Out:
# C:\Users\dazb\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\utils.py:281: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   ndistinct = ids.apply(len_unique, axis=0).as_matrix()
# C:\Users\dazb\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\dazb\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# <ggplot: (-9223371945399106030)>
